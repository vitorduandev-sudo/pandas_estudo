# %%
import pandas as pd
import numpy as np

# %%
# Criação de um DataFrame para a manipulação dos dados
df = pd.read_csv("dataset_avicola_simulado.csv")
df = pd.DataFrame(df)

# %%
#Verificar versão da biblioteca pandas
print(pd.__version__)
# Out:
# 3.0.5

# %%
# mostra as primeiras linhas do dataframe
print(df.head())
# Mostra os ultimos registros do DataFrame.
print(df.tail())

# tambem podemos informar quantos registros queremos
# Out:
#              timestamp  temperatura_ar  umidade_relativa  amonia  \
# 0  2025-01-01 00:00:00           21.65             85.66   15.81
# 1  2025-01-01 00:15:00           21.09             86.28   13.92
# 2  2025-01-01 00:30:00           20.75             88.13   10.84
# 3  2025-01-01 00:45:00           20.82             85.07   10.59
# 4  2025-01-01 01:00:00           20.13             88.95    8.47
#
#    temperatura_globo_negro  ponto_orvalho   itgu
# 0                    23.68          19.14  72.07
# 1                    23.81          18.70  72.04
# 2                    22.47          18.71  70.71
# 3                    21.57          18.22  69.62
# 4                    21.73          18.25  69.80
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 667  2025-01-07 22:45:00           23.33             82.05   13.46
# 668  2025-01-07 23:00:00           22.84             81.37    7.09
# 669  2025-01-07 23:15:00           22.52             80.84   11.34
# 670  2025-01-07 23:30:00           22.32             83.69   13.83
# 671  2025-01-07 23:45:00           21.87             85.51    8.16
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 667                    25.15          20.09  73.89
# 668                    24.52          19.48  73.03
# 669                    24.61          19.07  72.98
# 670                    23.97          19.43  72.46
# 671                    23.97          19.33  72.43

# %%
''' df.info()
    Mostra as informaçoes da tabela:
    * Quantidade de linhas
    * Nomes das colunas
    * Tipos dos dados
    * Valores Vazios
'''
print("Agora estou mostrando as informaçoes do DataSet:")
print()
print(df.info())
# Out:
# Agora estou mostrando as informaçoes do DataSet:
#
# <class 'pandas.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                672 non-null    str
#  1   temperatura_ar           672 non-null    float64
#  2   umidade_relativa         672 non-null    float64
#  3   amonia                   672 non-null    float64
#  4   temperatura_globo_negro  672 non-null    float64
#  5   ponto_orvalho            672 non-null    float64
#  6   itgu                     672 non-null    float64
# dtypes: float64(6), str(1)
# memory usage: 36.9 KB
# None

# %%
''' df.describe()
    Mostra a descrição da tabela
    * Media
    * Valor Minimo
    * Valor Maximo
    * quantidade
    * Desvio padrao
    * etc
''' 
print("Agora estou mostrando as descricoes das tabelas:")
print()
print(df.describe())
# Out:
# Agora estou mostrando as descricoes das tabelas:
#
#        temperatura_ar  umidade_relativa      amonia  temperatura_globo_negro  \
# count      672.000000        672.000000  672.000000               672.000000
# mean        27.238289         69.764554   12.057664                30.787039
# std          5.413110         14.871810    2.519820                 6.906385
# min         19.140000         37.390000    4.650000                20.590000
# 25%         22.115000         56.102500   10.317500                24.180000
# 50%         26.930000         70.180000   12.020000                30.485000
# 75%         31.930000         84.170000   13.722500                36.830000
# max         41.700000         94.660000   19.980000                48.480000
#
#        ponto_orvalho        itgu
# count     672.000000  672.000000
# mean       20.743036   79.754702
# std         1.619484    7.450945
# min        17.540000   68.650000
# 25%        19.225000   72.587500
# 50%        21.015000   79.610000
# 75%        21.940000   86.272500
# max        25.560000   98.820000

# %%
''' df.shape()
    Mostra a quantidade de linhas e colunas
    Saida:
    (x,y)
    x = Linhas
    y = colunas
'''
print("Agora estou mostrando a quantidade de linhas e colunas:")
print()
print(df.shape)
# Out:
# Agora estou mostrando a quantidade de linhas e colunas:
#
# (672, 7)

# %%
''' df.columns
    Mostra os nomes das colunas
'''
print("Agora estou mostrando os nomes das colunas:")
print()
print(df.columns)
# Out:
# Agora estou mostrando os nomes das colunas:
#
# Index(['timestamp', 'temperatura_ar', 'umidade_relativa', 'amonia',
#        'temperatura_globo_negro', 'ponto_orvalho', 'itgu'],
#       dtype='str')

# %%
''' df["temperatura_ar"] df[["temperatura_ar, amonia"]]
    Seleciona uma coluna ou mais
'''
print("Agora estou selecionando uma e duas tabelas:")
print()
print(df["temperatura_ar"])

print(df[["temperatura_ar", "amonia"]])
# Out:
# Agora estou selecionando uma e duas tabelas:
#
# 0      21.65
# 1      21.09
# 2      20.75
# 3      20.82
# 4      20.13
#        ...
# 667    23.33
# 668    22.84
# 669    22.52
# 670    22.32
# 671    21.87
# Name: temperatura_ar, Length: 672, dtype: float64
#      temperatura_ar  amonia
# 0             21.65   15.81
# 1             21.09   13.92
# 2             20.75   10.84
# 3             20.82   10.59
# 4             20.13    8.47
# ..              ...     ...
# 667           23.33   13.46
# 668           22.84    7.09
# 669           22.52   11.34
# 670           22.32   13.83
# 671           21.87    8.16
#
# [672 rows x 2 columns]

# %%
print("-----EXERCICIOS-----")
# Out:
# -----EXERCICIOS-----

# %%
print("Quantidade de linhas:")
# para mostrar a quantidade de linhas utilizamos df.shape
print(f"existem {df.shape[0]} linhas ta tabela")
# Out:
# Quantidade de linhas:
# existem 672 linhas ta tabela

# %%
print("Quantidade de Colunas: ")
# Para mostrar a quantidade de colunas podemos utilizar df.shape
print(f"Exitem {df.shape[1]} colunas na tabela")
# Out:
# Quantidade de Colunas:
# Exitem 7 colunas na tabela

# %%
print("temperatura_ar media e amonia media")
# para calcular a media podemos utilizar a funcao mean()

print(f"a media da temperatura do ar é de {df["temperatura_ar"].mean():.2f}")
print(f"a media da amonia é de {df["amonia"].mean():.2f}")
# Out:
# temperatura_ar media e amonia media
# a media da temperatura do ar é de 27.24
# a media da amonia é de 12.06

# %%
print("maior e menor temperatura_ar")
# para calcular os valores maximos e minimos podemos utilizar as funcoes max() e min()

print(f"o maior temperatura_ar foi de {df['temperatura_ar'].max()}")
print(f"o menor temperatura_ar foi de {df['temperatura_ar'].min()}")
# Out:
# maior e menor temperatura_ar
# o maior temperatura_ar foi de 41.7
# o menor temperatura_ar foi de 19.14

# %%
print("-----FILTROS-----")
# Out:
# -----FILTROS-----

# %%
print("todos registros que tiveram a temperatura_ar maior que 30")
print(df[df["temperatura_ar" ] > 30])
# Out:
# todos registros que tiveram a temperatura_ar maior que 30
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 41   2025-01-01 10:15:00           30.48             61.77   16.74
# 42   2025-01-01 10:30:00           30.40             58.87    9.96
# 43   2025-01-01 10:45:00           30.86             59.40   14.07
# 44   2025-01-01 11:00:00           31.27             60.01   18.80
# 45   2025-01-01 11:15:00           31.87             55.53   13.21
# ..                   ...             ...               ...     ...
# 646  2025-01-07 17:30:00           32.39             54.92   11.49
# 647  2025-01-07 17:45:00           31.30             56.72   10.86
# 648  2025-01-07 18:00:00           31.24             57.91    6.38
# 649  2025-01-07 18:15:00           30.65             59.21   10.77
# 652  2025-01-07 19:00:00           30.04             64.26    9.16
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 41                     34.89          22.31  84.42
# 42                     34.56          21.45  83.78
# 43                     35.64          22.02  85.07
# 44                     35.85          22.57  85.47
# 45                     35.90          21.85  85.27
# ..                       ...            ...    ...
# 646                    36.20          22.16  85.68
# 647                    37.05          21.67  86.35
# 648                    36.40          21.96  85.81
# 649                    36.10          21.77  85.44
# 652                    34.27          22.54  83.88
#
# [239 rows x 7 columns]

# %%
print("todos registros que tiveram a amonia maior que 10")
print(df[df["amonia"] > 10])
# Out:
# todos registros que tiveram a amonia maior que 10
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 0    2025-01-01 00:00:00           21.65             85.66   15.81
# 1    2025-01-01 00:15:00           21.09             86.28   13.92
# 2    2025-01-01 00:30:00           20.75             88.13   10.84
# 3    2025-01-01 00:45:00           20.82             85.07   10.59
# 6    2025-01-01 01:30:00           20.02             89.48   12.94
# ..                   ...             ...               ...     ...
# 663  2025-01-07 21:45:00           24.95             77.97   14.14
# 664  2025-01-07 22:00:00           23.88             78.99   13.38
# 667  2025-01-07 22:45:00           23.33             82.05   13.46
# 669  2025-01-07 23:15:00           22.52             80.84   11.34
# 670  2025-01-07 23:30:00           22.32             83.69   13.83
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 0                      23.68          19.14  72.07
# 1                      23.81          18.70  72.04
# 2                      22.47          18.71  70.71
# 3                      21.57          18.22  69.62
# 6                      21.23          18.24  69.30
# ..                       ...            ...    ...
# 663                    27.28          20.84  76.28
# 664                    27.14          20.02  75.85
# 667                    25.15          20.09  73.89
# 669                    24.61          19.07  72.98
# 670                    23.97          19.43  72.46
#
# [527 rows x 7 columns]

# %%
print("todos registros que tiveram a temperatura_ar menor que 25")
print(df[df["temperatura_ar"] < 25])
# Out:
# todos registros que tiveram a temperatura_ar menor que 25
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 0    2025-01-01 00:00:00           21.65             85.66   15.81
# 1    2025-01-01 00:15:00           21.09             86.28   13.92
# 2    2025-01-01 00:30:00           20.75             88.13   10.84
# 3    2025-01-01 00:45:00           20.82             85.07   10.59
# 4    2025-01-01 01:00:00           20.13             88.95    8.47
# ..                   ...             ...               ...     ...
# 667  2025-01-07 22:45:00           23.33             82.05   13.46
# 668  2025-01-07 23:00:00           22.84             81.37    7.09
# 669  2025-01-07 23:15:00           22.52             80.84   11.34
# 670  2025-01-07 23:30:00           22.32             83.69   13.83
# 671  2025-01-07 23:45:00           21.87             85.51    8.16
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 0                      23.68          19.14  72.07
# 1                      23.81          18.70  72.04
# 2                      22.47          18.71  70.71
# 3                      21.57          18.22  69.62
# 4                      21.73          18.25  69.80
# ..                       ...            ...    ...
# 667                    25.15          20.09  73.89
# 668                    24.52          19.48  73.03
# 669                    24.61          19.07  72.98
# 670                    23.97          19.43  72.46
# 671                    23.97          19.33  72.43
#
# [272 rows x 7 columns]

# %%
print("todos registros que tiveram a amonia igual a 5")
print(df[df["amonia"] == 5])
# Out:
# todos registros que tiveram a amonia igual a 5
# Empty DataFrame
# Columns: [timestamp, temperatura_ar, umidade_relativa, amonia, temperatura_globo_negro, ponto_orvalho, itgu]
# Index: []

# %%
print("todos registros que tiveram a temperatura_ar maior ou igual a 30")
print(df[df["temperatura_ar"] >= 30])
# Out:
# todos registros que tiveram a temperatura_ar maior ou igual a 30
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 39   2025-01-01 09:45:00           30.00             64.28   13.64
# 41   2025-01-01 10:15:00           30.48             61.77   16.74
# 42   2025-01-01 10:30:00           30.40             58.87    9.96
# 43   2025-01-01 10:45:00           30.86             59.40   14.07
# 44   2025-01-01 11:00:00           31.27             60.01   18.80
# ..                   ...             ...               ...     ...
# 646  2025-01-07 17:30:00           32.39             54.92   11.49
# 647  2025-01-07 17:45:00           31.30             56.72   10.86
# 648  2025-01-07 18:00:00           31.24             57.91    6.38
# 649  2025-01-07 18:15:00           30.65             59.21   10.77
# 652  2025-01-07 19:00:00           30.04             64.26    9.16
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 39                     32.80          22.51  82.40
# 41                     34.89          22.31  84.42
# 42                     34.56          21.45  83.78
# 43                     35.64          22.02  85.07
# 44                     35.85          22.57  85.47
# ..                       ...            ...    ...
# 646                    36.20          22.16  85.68
# 647                    37.05          21.67  86.35
# 648                    36.40          21.96  85.81
# 649                    36.10          21.77  85.44
# 652                    34.27          22.54  83.88
#
# [240 rows x 7 columns]

# %%
print("todos registros que tiveram a temperatura_ar maior que 30 E amonia > 10")
print(df[(df["temperatura_ar"] > 30) & (df["amonia"] > 10)])
# Out:
# todos registros que tiveram a temperatura_ar maior que 30 E amonia > 10
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 41   2025-01-01 10:15:00           30.48             61.77   16.74
# 43   2025-01-01 10:45:00           30.86             59.40   14.07
# 44   2025-01-01 11:00:00           31.27             60.01   18.80
# 45   2025-01-01 11:15:00           31.87             55.53   13.21
# 46   2025-01-01 11:30:00           31.86             56.93   11.82
# ..                   ...             ...               ...     ...
# 644  2025-01-07 17:00:00           33.14             55.63   16.40
# 645  2025-01-07 17:15:00           32.41             55.55   15.06
# 646  2025-01-07 17:30:00           32.39             54.92   11.49
# 647  2025-01-07 17:45:00           31.30             56.72   10.86
# 649  2025-01-07 18:15:00           30.65             59.21   10.77
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 41                     34.89          22.31  84.42
# 43                     35.64          22.02  85.07
# 44                     35.85          22.57  85.47
# 45                     35.90          21.85  85.27
# 46                     37.10          22.26  86.61
# ..                       ...            ...    ...
# 644                    37.78          23.06  87.58
# 645                    37.24          22.36  86.79
# 646                    36.20          22.16  85.68
# 647                    37.05          21.67  86.35
# 649                    36.10          21.77  85.44
#
# [192 rows x 7 columns]

# %%
print("todos registros que tiveram a temperatura_ar menor que 25 E amonia menor que 5")
print(df[(df["temperatura_ar"] < 25) & (df["amonia"] < 5)])
# Out:
# todos registros que tiveram a temperatura_ar menor que 25 E amonia menor que 5
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 384  2025-01-05 00:00:00           21.65             85.07    4.82
# 397  2025-01-05 03:15:00           19.80             89.74    4.70
# 492  2025-01-06 03:00:00           19.98             91.53    4.65
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 384                    22.77          19.03  71.13
# 397                    21.14          18.07  69.14
# 492                    21.87          18.56  70.06

# %%
print("todos registros que tiveram a temperatura_ar maior que 35 OU amonia maior que 15")
print(df[(df["temperatura_ar"] > 35) | (df["amonia"] > 15)])
# Out:
# todos registros que tiveram a temperatura_ar maior que 35 OU amonia maior que 15
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 0    2025-01-01 00:00:00           21.65             85.66   15.81
# 7    2025-01-01 01:45:00           19.89             89.18   16.63
# 17   2025-01-01 04:15:00           20.87             86.97   15.85
# 33   2025-01-01 08:15:00           26.12             72.02   15.87
# 41   2025-01-01 10:15:00           30.48             61.77   16.74
# ..                   ...             ...               ...     ...
# 644  2025-01-07 17:00:00           33.14             55.63   16.40
# 645  2025-01-07 17:15:00           32.41             55.55   15.06
# 654  2025-01-07 19:30:00           28.52             64.95   15.64
# 655  2025-01-07 19:45:00           28.65             67.28   15.53
# 662  2025-01-07 21:30:00           25.19             76.53   15.80
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 0                      23.68          19.14  72.07
# 7                      21.37          18.06  69.37
# 17                     22.61          18.62  70.81
# 33                     29.45          20.67  78.39
# 41                     34.89          22.31  84.42
# ..                       ...            ...    ...
# 644                    37.78          23.06  87.58
# 645                    37.24          22.36  86.79
# 654                    33.06          21.28  82.22
# 655                    32.30          21.98  81.71
# 662                    27.72          20.77  76.69
#
# [104 rows x 7 columns]

# %%
print("todos registros que tiveram a temperatura_ar maior que 25 E temperatura_ar menor que 30")
print(df[(df["temperatura_ar"] > 25) & (df["temperatura_ar"] < 30)])
# Out:
# todos registros que tiveram a temperatura_ar maior que 25 E temperatura_ar menor que 30
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 30   2025-01-01 07:30:00           25.50             73.81    8.50
# 31   2025-01-01 07:45:00           25.87             77.19   10.58
# 32   2025-01-01 08:00:00           26.13             71.86   12.17
# 33   2025-01-01 08:15:00           26.12             72.02   15.87
# 34   2025-01-01 08:30:00           26.69             69.52    8.92
# ..                   ...             ...               ...     ...
# 658  2025-01-07 20:30:00           27.08             70.47   14.68
# 659  2025-01-07 20:45:00           26.62             72.72   12.99
# 660  2025-01-07 21:00:00           26.81             72.28   10.37
# 661  2025-01-07 21:15:00           25.20             72.72    8.49
# 662  2025-01-07 21:30:00           25.19             76.53   15.80
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 30                     28.87          20.49  77.75
# 31                     28.25          21.56  77.51
# 32                     28.55          20.65  77.48
# 33                     29.45          20.67  78.39
# 34                     30.91          20.65  79.84
# ..                       ...            ...    ...
# 658                    31.35          21.24  80.50
# 659                    29.40          21.31  78.57
# 660                    28.90          21.40  78.10
# 661                    28.56          19.95  77.24
# 662                    27.72          20.77  76.69
#
# [159 rows x 7 columns]

# %%
print("Encontre todos os registros onde amonia maior que 10 e mostre a media desse registro")
print(f"a media desses registros é de: {df[df["amonia"] > 10] ["amonia"].mean():.2f}")
# Out:
# Encontre todos os registros onde amonia maior que 10 e mostre a media desse registro
# a media desses registros é de: 12.99

# %%
print("Descubra a maior concentração de amonia somente quando: temperatura_ar for maior que 30")
print(f"a maior concentracao de amonia nesse intervalo foi de {df[df["temperatura_ar"] > 30] ["temperatura_ar"].max():.2f}")
# Out:
# Descubra a maior concentração de amonia somente quando: temperatura_ar for maior que 30
# a maior concentracao de amonia nesse intervalo foi de 41.70

# %%
print("------TREINAMENTO DIA 03/09/26")
# Out:
# ------TREINAMENTO DIA 03/09/26

# %%
print("Mostre quanros registros existem no DataSet:")
print(f"Existem {df.shape[0]} registros no dataset")
# Out:
# Mostre quanros registros existem no DataSet:
# Existem 672 registros no dataset

# %%
print("Calcule a média da coluna temperatura_ar:")
print(f"A media das temperaturas da coluna temperatura_ar é de {df["temperatura_ar"].mean():.2f}")
# Out:
# Calcule a média da coluna temperatura_ar:
# A media das temperaturas da coluna temperatura_ar é de 27.24

# %%
print("Calcule a média da coluna amonia:")
print(f"A media na coluna amonia foi de {df['amonia'].mean()}")
# Out:
# Calcule a média da coluna amonia:
# A media na coluna amonia foi de 12.05766369047619

# %%
print("Descubra a maior temperatura registrada:")
print(f"A maior temperatura registrada foi de {df['temperatura_ar'].max()}")
# Out:
# Descubra a maior temperatura registrada:
# A maior temperatura registrada foi de 41.7

# %%
print("Descubra a menor temperatura registrada")
print(f"A menor temperatura registrada foi de {df['temperatura_ar'].min()}")
# Out:
# Descubra a menor temperatura registrada
# A menor temperatura registrada foi de 19.14

# %%
print("Descubra a menor concentração de amônia registrada")
print(f"A menor concentração de amonia utilizada foi de {df['amonia'].min()}")
# Out:
# Descubra a menor concentração de amônia registrada
# A menor concentração de amonia utilizada foi de 4.65

# %%
print("Mostre somente as colunas: timestamp, temperatura_ar, umidade_relativa")
print(df[["timestamp", "temperatura_ar", "umidade_relativa"]])
# Out:
# Mostre somente as colunas: timestamp, temperatura_ar, umidade_relativa
#                timestamp  temperatura_ar  umidade_relativa
# 0    2025-01-01 00:00:00           21.65             85.66
# 1    2025-01-01 00:15:00           21.09             86.28
# 2    2025-01-01 00:30:00           20.75             88.13
# 3    2025-01-01 00:45:00           20.82             85.07
# 4    2025-01-01 01:00:00           20.13             88.95
# ..                   ...             ...               ...
# 667  2025-01-07 22:45:00           23.33             82.05
# 668  2025-01-07 23:00:00           22.84             81.37
# 669  2025-01-07 23:15:00           22.52             80.84
# 670  2025-01-07 23:30:00           22.32             83.69
# 671  2025-01-07 23:45:00           21.87             85.51
#
# [672 rows x 3 columns]

# %%
print("Descubra o tipo de dado (dtype) de cada coluna.")
# para descobrir o tipo de dado de uma coluna podemos utilizar a funcao df.dtypes
print(df.dtypes)
# Out:
# Descubra o tipo de dado (dtype) de cada coluna.
# timestamp                      str
# temperatura_ar             float64
# umidade_relativa           float64
# amonia                     float64
# temperatura_globo_negro    float64
# ponto_orvalho              float64
# itgu                       float64
# dtype: object

# %%
print("Descubra quantos valores únicos existem na coluna timestamp")
# Conta a quantidade de valores únicos na coluna timestamp
print(f"existem {df['timestamp'].nunique()} valores unicos na coluna")
# Out:
# Descubra quantos valores únicos existem na coluna timestamp
# existem 672 valores unicos na coluna

# %%
print("Descubra se existem valores nulos em alguma das 7 colunas.")
# Verifica a quantidade de valores nulos (ausentes) em cada coluna
print(df.isnull().sum())
# Out:
# Descubra se existem valores nulos em alguma das 7 colunas.
# timestamp                  0
# temperatura_ar             0
# umidade_relativa           0
# amonia                     0
# temperatura_globo_negro    0
# ponto_orvalho              0
# itgu                       0
# dtype: int64

# %%
print("Calcule a média de: temperatura_ar, umidade_relativa, amonia, temperatura_globo_negro, ponto_orvalho, itgu")
print(df[["temperatura_ar", "umidade_relativa", "amonia", "temperatura_globo_negro", "ponto_orvalho", "itgu"]].mean())
# Out:
# Calcule a média de: temperatura_ar, umidade_relativa, amonia, temperatura_globo_negro, ponto_orvalho, itgu
# temperatura_ar             27.238289
# umidade_relativa           69.764554
# amonia                     12.057664
# temperatura_globo_negro    30.787039
# ponto_orvalho              20.743036
# itgu                       79.754702
# dtype: float64

# %%
print("Descubra a maior umidade relativa:")
print(f"A maior umidade relativa foi de {df["umidade_relativa"].max()}")
# Out:
# Descubra a maior umidade relativa:
# A maior umidade relativa foi de 94.66

# %%
print("Descubra a menor umidade relativa.")
print(f"A menor umidade relativa foi de {df["umidade_relativa"].min()}")
# Out:
# Descubra a menor umidade relativa.
# A menor umidade relativa foi de 37.39

# %%
print("Descubra a maior temperatura de globo negro.")
print(f"A maior temperatura do globo negro foi de {df["temperatura_globo_negro"].max()}")
# Out:
# Descubra a maior temperatura de globo negro.
# A maior temperatura do globo negro foi de 48.48

# %%
print("Descubra o maior valor de ITGU.")
print(f"o maior valor do itgu foi de {df["itgu"].max()}")
# Out:
# Descubra o maior valor de ITGU.
# o maior valor do itgu foi de 98.82

# %%
print("Descubra o menor valor de ITGU.")
print(f"o menor valor do itgu foi de {df['itgu'].min()}")
# Out:
# Descubra o menor valor de ITGU.
# o menor valor do itgu foi de 68.65

# %%
print("---------- EXERCICIOS 04/09/26 ----------")
# Out:
# ---------- EXERCICIOS 04/09/26 ----------

# %%
''' df.sort_values()
    Serve para ordenar os registros do DataFrame
    de acordo com uma determinada coluna.

    Podemos ordenar:
    * Do menor para o maior
    * Do maior para o menor

    Para ordenar do maior para o menor utilizamos:
    ascending=False
'''

print("Ordene o DataFrame pela coluna temperatura_ar, da menor para a maior.")
print(df.sort_values("temperatura_ar"))
# Out:
# Ordene o DataFrame pela coluna temperatura_ar, da menor para a maior.
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 586  2025-01-07 02:30:00           19.14             91.65    9.84
# 489  2025-01-06 02:15:00           19.16             94.66   12.56
# 394  2025-01-05 02:30:00           19.35             91.75    9.97
# 11   2025-01-01 02:45:00           19.42             88.88   14.64
# 392  2025-01-05 02:00:00           19.43             89.04    8.86
# ..                   ...             ...               ...     ...
# 245  2025-01-03 13:15:00           40.94             41.20   11.88
# 251  2025-01-03 14:45:00           41.26             40.13   13.59
# 252  2025-01-03 15:00:00           41.36             38.87   12.49
# 250  2025-01-03 14:30:00           41.56             40.89   10.38
# 249  2025-01-03 14:15:00           41.70             40.50   13.43
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 586                    21.26          17.75  69.15
# 489                    22.05          18.28  70.13
# 394                    21.13          17.98  69.10
# 11                     21.29          17.54  69.10
# 392                    21.97          17.58  69.80
# ..                       ...            ...    ...
# 245                    46.94          25.14  97.49
# 251                    48.33          24.99  98.82
# 252                    48.48          24.54  98.81
# 250                    47.93          25.56  98.63
# 249                    47.60          25.53  98.29
#
# [672 rows x 7 columns]

# %%
print("Ordene o DataFrame pela coluna temperatura_ar, da maior para a menor.")
print(df.sort_values("temperatura_ar", ascending=False))
# Out:
# Ordene o DataFrame pela coluna temperatura_ar, da maior para a menor.
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 249  2025-01-03 14:15:00           41.70             40.50   13.43
# 250  2025-01-03 14:30:00           41.56             40.89   10.38
# 252  2025-01-03 15:00:00           41.36             38.87   12.49
# 251  2025-01-03 14:45:00           41.26             40.13   13.59
# 245  2025-01-03 13:15:00           40.94             41.20   11.88
# ..                   ...             ...               ...     ...
# 392  2025-01-05 02:00:00           19.43             89.04    8.86
# 11   2025-01-01 02:45:00           19.42             88.88   14.64
# 394  2025-01-05 02:30:00           19.35             91.75    9.97
# 489  2025-01-06 02:15:00           19.16             94.66   12.56
# 586  2025-01-07 02:30:00           19.14             91.65    9.84
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 249                    47.60          25.53  98.29
# 250                    47.93          25.56  98.63
# 252                    48.48          24.54  98.81
# 251                    48.33          24.99  98.82
# 245                    46.94          25.14  97.49
# ..                       ...            ...    ...
# 392                    21.97          17.58  69.80
# 11                     21.29          17.54  69.10
# 394                    21.13          17.98  69.10
# 489                    22.05          18.28  70.13
# 586                    21.26          17.75  69.15
#
# [672 rows x 7 columns]

# %%
''' df.head()
    Mostra os primeiros registros do DataFrame.

    Podemos informar dentro dos parenteses quantos
    registros queremos visualizar.

    Exemplo:
    df.head(10)

    Mostra os 10 primeiros registros.
'''

''' df.tail()
    Mostra os ultimos registros do DataFrame.

    Tambem podemos informar quantos registros queremos.
'''

print("Mostre somente os 5 registros com maior temperatura_ar.")
print(f"As 5 maiores temperaturas foram de:{df.sort_values(by='temperatura_ar', ascending=False).head(5)}")
# Out:
# Mostre somente os 5 registros com maior temperatura_ar.
# As 5 maiores temperaturas foram de:               timestamp  temperatura_ar  umidade_relativa  amonia  \
# 249  2025-01-03 14:15:00           41.70             40.50   13.43
# 250  2025-01-03 14:30:00           41.56             40.89   10.38
# 252  2025-01-03 15:00:00           41.36             38.87   12.49
# 251  2025-01-03 14:45:00           41.26             40.13   13.59
# 245  2025-01-03 13:15:00           40.94             41.20   11.88
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 249                    47.60          25.53  98.29
# 250                    47.93          25.56  98.63
# 252                    48.48          24.54  98.81
# 251                    48.33          24.99  98.82
# 245                    46.94          25.14  97.49

# %%
print("Mostre somente os 5 registros com maior amonia.")
print(f"As 5 maiores Amonias foram de\n'{df.sort_values("amonia", ascending=False).head(5)}")
# Out:
# Mostre somente os 5 registros com maior amonia.
# As 5 maiores Amonias foram de
# '               timestamp  temperatura_ar  umidade_relativa  amonia  \
# 403  2025-01-05 04:45:00           21.53             86.51   19.98
# 508  2025-01-06 07:00:00           24.51             78.41   18.90
# 44   2025-01-01 11:00:00           31.27             60.01   18.80
# 188  2025-01-02 23:00:00           22.35             83.76   18.58
# 372  2025-01-04 21:00:00           25.48             74.50   18.40
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 403                    22.93          19.19  71.33
# 508                    27.59          20.51  76.47
# 44                     35.85          22.57  85.47
# 188                    24.55          19.46  73.05
# 372                    29.05          20.61  77.97

# %%
print("Mostre os 10 registros com menor itgu.")
print(df.sort_values("itgu").head(10))
# Out:
# Mostre os 10 registros com menor itgu.
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 390  2025-01-05 01:30:00           20.23             88.20   14.21
# 298  2025-01-04 02:30:00           19.76             90.48   13.10
# 9    2025-01-01 02:15:00           20.10             87.02   12.49
# 589  2025-01-07 03:15:00           19.99             89.83   13.02
# 590  2025-01-07 03:30:00           19.83             87.29   14.78
# 398  2025-01-05 03:30:00           20.41             90.67    9.48
# 110  2025-01-02 03:30:00           20.39             89.27   11.78
# 107  2025-01-02 02:45:00           20.44             87.32    6.90
# 109  2025-01-02 03:15:00           20.79             87.55   11.86
# 487  2025-01-06 01:45:00           20.58             89.54   15.15
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 390                    20.59          18.21  68.65
# 298                    20.70          18.16  68.74
# 9                      20.86          17.87  68.79
# 589                    20.78          18.27  68.86
# 590                    21.05          17.65  68.90
# 398                    20.63          18.84  68.91
# 110                    20.77          18.57  68.96
# 107                    20.93          18.26  69.00
# 109                    20.82          18.64  69.03
# 487                    20.79          18.80  69.06

# %%
print("Mostre os primeiros 10 registros do dataset.")
print(df.head(10))

print(" Mostre os últimos 10 registros do dataset.")
print(df.tail(10))
# Out:
# Mostre os primeiros 10 registros do dataset.
#              timestamp  temperatura_ar  umidade_relativa  amonia  \
# 0  2025-01-01 00:00:00           21.65             85.66   15.81
# 1  2025-01-01 00:15:00           21.09             86.28   13.92
# 2  2025-01-01 00:30:00           20.75             88.13   10.84
# 3  2025-01-01 00:45:00           20.82             85.07   10.59
# 4  2025-01-01 01:00:00           20.13             88.95    8.47
# 5  2025-01-01 01:15:00           20.96             88.60    8.44
# 6  2025-01-01 01:30:00           20.02             89.48   12.94
# 7  2025-01-01 01:45:00           19.89             89.18   16.63
# 8  2025-01-01 02:00:00           20.05             88.24    8.95
# 9  2025-01-01 02:15:00           20.10             87.02   12.49
#
#    temperatura_globo_negro  ponto_orvalho   itgu
# 0                    23.68          19.14  72.07
# 1                    23.81          18.70  72.04
# 2                    22.47          18.71  70.71
# 3                    21.57          18.22  69.62
# 4                    21.73          18.25  69.80
# 5                    22.01          19.00  70.35
# 6                    21.23          18.24  69.30
# 7                    21.37          18.06  69.37
# 8                    21.99          18.05  69.99
# 9                    20.86          17.87  68.79
#  Mostre os últimos 10 registros do dataset.
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 662  2025-01-07 21:30:00           25.19             76.53   15.80
# 663  2025-01-07 21:45:00           24.95             77.97   14.14
# 664  2025-01-07 22:00:00           23.88             78.99   13.38
# 665  2025-01-07 22:15:00           23.43             77.50    9.63
# 666  2025-01-07 22:30:00           23.69             77.95    8.92
# 667  2025-01-07 22:45:00           23.33             82.05   13.46
# 668  2025-01-07 23:00:00           22.84             81.37    7.09
# 669  2025-01-07 23:15:00           22.52             80.84   11.34
# 670  2025-01-07 23:30:00           22.32             83.69   13.83
# 671  2025-01-07 23:45:00           21.87             85.51    8.16
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 662                    27.72          20.77  76.69
# 663                    27.28          20.84  76.28
# 664                    27.14          20.02  75.85
# 665                    26.82          19.27  75.26
# 666                    26.42          19.61  74.98
# 667                    25.15          20.09  73.89
# 668                    24.52          19.48  73.03
# 669                    24.61          19.07  72.98
# 670                    23.97          19.43  72.46
# 671                    23.97          19.33  72.43

# %%
print("Ordene pela temperatura_ar do maior para o menor e mostre os 10 primeiros.")
print(df.sort_values("temperatura_ar", ascending=False).head(10))
# Out:
# Ordene pela temperatura_ar do maior para o menor e mostre os 10 primeiros.
#                timestamp  temperatura_ar  umidade_relativa  amonia  \
# 249  2025-01-03 14:15:00           41.70             40.50   13.43
# 250  2025-01-03 14:30:00           41.56             40.89   10.38
# 252  2025-01-03 15:00:00           41.36             38.87   12.49
# 251  2025-01-03 14:45:00           41.26             40.13   13.59
# 245  2025-01-03 13:15:00           40.94             41.20   11.88
# 248  2025-01-03 14:00:00           40.84             38.65   11.30
# 247  2025-01-03 13:45:00           40.78             39.92    6.90
# 246  2025-01-03 13:30:00           40.76             38.44   14.19
# 253  2025-01-03 15:15:00           40.67             40.39   12.49
# 541  2025-01-06 15:15:00           40.50             39.86    8.86
#
#      temperatura_globo_negro  ponto_orvalho   itgu
# 249                    47.60          25.53  98.29
# 250                    47.93          25.56  98.63
# 252                    48.48          24.54  98.81
# 251                    48.33          24.99  98.82
# 245                    46.94          25.14  97.49
# 248                    47.32          23.98  97.46
# 247                    47.83          24.47  98.14
# 246                    48.35          23.82  98.42
# 253                    47.36          24.57  97.71
# 541                    46.12          24.19  96.33

# %%
''' value_counts()
    Conta quantas vezes cada valor aparece em uma coluna.

    É muito utilizado para descobrir a quantidade
    de ocorrencias de cada valor.

    Pode ser utilizado em uma coluna do DataFrame.
'''

print("Descubra quantos registros existem para cada timestamp.")
print(df.value_counts("timestamp"))
# Out:
# Descubra quantos registros existem para cada timestamp.
# timestamp
# 2025-01-01 00:00:00    1
# 2025-01-01 00:15:00    1
# 2025-01-01 00:30:00    1
# 2025-01-01 00:45:00    1
# 2025-01-01 01:00:00    1
#                       ..
# 2025-01-07 22:45:00    1
# 2025-01-07 23:00:00    1
# 2025-01-07 23:15:00    1
# 2025-01-07 23:30:00    1
# 2025-01-07 23:45:00    1
# Name: count, Length: 672, dtype: int64

# %%
print("Estudo 09/09/2026")

# %%
print("Mostre somente as linhas onde: temperatura_ar > 30 e mostre somente: temperatura_ar, amonia,itgu")

print(df.loc[df["temperatura_ar"] > 30, ["temperatura_ar","amonia","itgu"]])
# Out:
# Mostre somente as linhas onde: temperatura_ar > 30 e mostre somente: temperatura_ar, amonia,itgu
#      temperatura_ar  amonia   itgu
# 41            30.48   16.74  84.42
# 42            30.40    9.96  83.78
# 43            30.86   14.07  85.07
# 44            31.27   18.80  85.47
# 45            31.87   13.21  85.27
# ..              ...     ...    ...
# 646           32.39   11.49  85.68
# 647           31.30   10.86  86.35
# 648           31.24    6.38  85.81
# 649           30.65   10.77  85.44
# 652           30.04    9.16  83.88
#
# [239 rows x 3 columns]

# %%
print("Usando loc, mostre os registros onde: amonia > 10 e mostre somente: temperatura_ar amonia itgu")

print(df.loc[df["amonia"] > 10, ["temperatura_ar", "amonia", "itgu"]])
# Out:
# Usando loc, mostre os registros onde: amonia > 10 e mostre somente: temperatura_ar amonia itgu
#      temperatura_ar  amonia   itgu
# 0             21.65   15.81  72.07
# 1             21.09   13.92  72.04
# 2             20.75   10.84  70.71
# 3             20.82   10.59  69.62
# 6             20.02   12.94  69.30
# ..              ...     ...    ...
# 663           24.95   14.14  76.28
# 664           23.88   13.38  75.85
# 667           23.33   13.46  73.89
# 669           22.52   11.34  72.98
# 670           22.32   13.83  72.46
#
# [527 rows x 3 columns]

# %%
'''
df.loc[
    CONDIÇÃO,
    COLUNAS
]
'''
# Out:
# '\ndf.loc[\n    CONDIÇÃO,\n    COLUNAS\n]\n'

# %%
print("Mostre somente: timestamp, temperatura_ar, amonia, quando:, temperatura_ar > 30")

print(df.loc
    [df["temperatura_ar"] > 30,
     ["timestamp", "temperatura_ar", "amonia"]]
)
# Out:
# Mostre somente: timestamp, temperatura_ar, amonia, quando:, temperatura_ar > 30
#                timestamp  temperatura_ar  amonia
# 41   2025-01-01 10:15:00           30.48   16.74
# 42   2025-01-01 10:30:00           30.40    9.96
# 43   2025-01-01 10:45:00           30.86   14.07
# 44   2025-01-01 11:00:00           31.27   18.80
# 45   2025-01-01 11:15:00           31.87   13.21
# ..                   ...             ...     ...
# 646  2025-01-07 17:30:00           32.39   11.49
# 647  2025-01-07 17:45:00           31.30   10.86
# 648  2025-01-07 18:00:00           31.24    6.38
# 649  2025-01-07 18:15:00           30.65   10.77
# 652  2025-01-07 19:00:00           30.04    9.16
#
# [239 rows x 3 columns]

# %%
print("timestamp, temperatura_ar, umidade_relativa quando: temperatura_ar < 25")

print(df.loc
      [df["temperatura_ar"] < 25,
       ["timestamp", "temperatura_ar", "umidade_relativa"]]
)
# Out:
# timestamp, temperatura_ar, umidade_relativa quando: temperatura_ar < 25
#                timestamp  temperatura_ar  umidade_relativa
# 0    2025-01-01 00:00:00           21.65             85.66
# 1    2025-01-01 00:15:00           21.09             86.28
# 2    2025-01-01 00:30:00           20.75             88.13
# 3    2025-01-01 00:45:00           20.82             85.07
# 4    2025-01-01 01:00:00           20.13             88.95
# ..                   ...             ...               ...
# 667  2025-01-07 22:45:00           23.33             82.05
# 668  2025-01-07 23:00:00           22.84             81.37
# 669  2025-01-07 23:15:00           22.52             80.84
# 670  2025-01-07 23:30:00           22.32             83.69
# 671  2025-01-07 23:45:00           21.87             85.51
#
# [272 rows x 3 columns]

# %%
print("mostre: timestamp, temperatura_ar, amonia, itgu quando: temperatura_ar > 30 e amonia > 10")

print(df.loc[
    (df["temperatura_ar"] > 30) & (df["amonia"] > 10),
    ["timestamp", "temperatura_ar", "amonia", "itgu"]
]
)
# Out:
# mostre: timestamp, temperatura_ar, amonia, itgu quando: temperatura_ar > 30 e amonia > 10
#                timestamp  temperatura_ar  amonia   itgu
# 41   2025-01-01 10:15:00           30.48   16.74  84.42
# 43   2025-01-01 10:45:00           30.86   14.07  85.07
# 44   2025-01-01 11:00:00           31.27   18.80  85.47
# 45   2025-01-01 11:15:00           31.87   13.21  85.27
# 46   2025-01-01 11:30:00           31.86   11.82  86.61
# ..                   ...             ...     ...    ...
# 644  2025-01-07 17:00:00           33.14   16.40  87.58
# 645  2025-01-07 17:15:00           32.41   15.06  86.79
# 646  2025-01-07 17:30:00           32.39   11.49  85.68
# 647  2025-01-07 17:45:00           31.30   10.86  86.35
# 649  2025-01-07 18:15:00           30.65   10.77  85.44
#
# [192 rows x 4 columns]

# %%
print("mostre: timestamp, temperatura_ar, umidade_relativa, amonia quando: temperatura_ar < 25 E amonia < 5")

print(df.loc[
    (df["temperatura_ar"] < 25) & (df["amonia"] < 5),
    ["timestamp","temperatura_ar","umidade_relativa"]
]

)
# Out:
# mostre: timestamp, temperatura_ar, umidade_relativa, amonia quando: temperatura_ar < 25 E amonia < 5
#                timestamp  temperatura_ar  umidade_relativa
# 384  2025-01-05 00:00:00           21.65             85.07
# 397  2025-01-05 03:15:00           19.80             89.74
# 492  2025-01-06 03:00:00           19.98             91.53

# %%
print("mostre timestamp, temperatura_ar, amonia, itgu quando: temperatura_ar > 35 OU amonia > 15")

print(df.loc[
    (df["temperatura_ar"] > 35) | (df["amonia"] > 15),
    ["timestamp", "temperatura_ar", "amonia", "itgu"]
]
)
# Out:
# mostre timestamp, temperatura_ar, amonia, itgu quando: temperatura_ar > 35 OU amonia > 15
#                timestamp  temperatura_ar  amonia   itgu
# 0    2025-01-01 00:00:00           21.65   15.81  72.07
# 7    2025-01-01 01:45:00           19.89   16.63  69.37
# 17   2025-01-01 04:15:00           20.87   15.85  70.81
# 33   2025-01-01 08:15:00           26.12   15.87  78.39
# 41   2025-01-01 10:15:00           30.48   16.74  84.42
# ..                   ...             ...     ...    ...
# 644  2025-01-07 17:00:00           33.14   16.40  87.58
# 645  2025-01-07 17:15:00           32.41   15.06  86.79
# 654  2025-01-07 19:30:00           28.52   15.64  82.22
# 655  2025-01-07 19:45:00           28.65   15.53  81.71
# 662  2025-01-07 21:30:00           25.19   15.80  76.69
#
# [104 rows x 4 columns]

# %%
print("ESTUDOS 10/09/26")
# Out:
# ESTUDOS 10/09/26

# %%
print("Mostre o registro de índice 0.")

print(df.iloc[0])
# Out:
# Mostre o registro de índice 0.
# timestamp                  2025-01-01 00:00:00
# temperatura_ar                           21.65
# umidade_relativa                         85.66
# amonia                                   15.81
# temperatura_globo_negro                  23.68
# ponto_orvalho                            19.14
# itgu                                     72.07
# Name: 0, dtype: object

# %%
print("Mostre os registros dos índices 0 até 5.")

print(df.iloc[0:6])
# Out:
# Mostre os registros dos índices 0 até 5.
#              timestamp  temperatura_ar  umidade_relativa  amonia  \
# 0  2025-01-01 00:00:00           21.65             85.66   15.81
# 1  2025-01-01 00:15:00           21.09             86.28   13.92
# 2  2025-01-01 00:30:00           20.75             88.13   10.84
# 3  2025-01-01 00:45:00           20.82             85.07   10.59
# 4  2025-01-01 01:00:00           20.13             88.95    8.47
# 5  2025-01-01 01:15:00           20.96             88.60    8.44
#
#    temperatura_globo_negro  ponto_orvalho   itgu
# 0                    23.68          19.14  72.07
# 1                    23.81          18.70  72.04
# 2                    22.47          18.71  70.71
# 3                    21.57          18.22  69.62
# 4                    21.73          18.25  69.80
# 5                    22.01          19.00  70.35

# %%
print("Mostre somente: temperatura_ar e amonia")

print(df.loc[
    :,
    ["temperatura_ar", "amonia"]
    ])
# Out:
# Mostre somente: temperatura_ar e amonia
#      temperatura_ar  amonia
# 0             21.65   15.81
# 1             21.09   13.92
# 2             20.75   10.84
# 3             20.82   10.59
# 4             20.13    8.47
# ..              ...     ...
# 667           23.33   13.46
# 668           22.84    7.09
# 669           22.52   11.34
# 670           22.32   13.83
# 671           21.87    8.16
#
# [672 rows x 2 columns]

# %%
print("Mostre os índices 0 até 9, somente com: timestamp temperatura_ar amonia")

print(df.loc[
    0:9,
    ["timestamp","temperatura_ar","amonia"]
])
# Out:
# Mostre os índices 0 até 9, somente com: timestamp temperatura_ar amonia
#              timestamp  temperatura_ar  amonia
# 0  2025-01-01 00:00:00           21.65   15.81
# 1  2025-01-01 00:15:00           21.09   13.92
# 2  2025-01-01 00:30:00           20.75   10.84
# 3  2025-01-01 00:45:00           20.82   10.59
# 4  2025-01-01 01:00:00           20.13    8.47
# 5  2025-01-01 01:15:00           20.96    8.44
# 6  2025-01-01 01:30:00           20.02   12.94
# 7  2025-01-01 01:45:00           19.89   16.63
# 8  2025-01-01 02:00:00           20.05    8.95
# 9  2025-01-01 02:15:00           20.10   12.49

# %%
print("Mostre os índices 10 até 20, somente com: temperatura_ar,umidade_relativa, itgu")

print(df.loc[
    10:20,
    ["temperatura_ar", "umidade_relativa", "itgu"]
])
# Out:
# Mostre os índices 10 até 20, somente com: temperatura_ar,umidade_relativa, itgu
#     temperatura_ar  umidade_relativa   itgu
# 10           20.30             90.26  69.65
# 11           19.42             88.88  69.10
# 12           20.20             87.18  69.72
# 13           19.86             90.53  70.27
# 14           19.90             88.85  69.96
# 15           20.18             88.66  69.49
# 16           20.86             90.51  70.58
# 17           20.87             86.97  70.81
# 18           20.92             89.67  69.79
# 19           21.21             86.18  71.33
# 20           21.36             86.40  72.44

# %%
print("Mostre a primeira linha usando iloc.")

print(df.iloc[0])
# Out:
# Mostre a primeira linha usando iloc.
# timestamp                  2025-01-01 00:00:00
# temperatura_ar                           21.65
# umidade_relativa                         85.66
# amonia                                   15.81
# temperatura_globo_negro                  23.68
# ponto_orvalho                            19.14
# itgu                                     72.07
# Name: 0, dtype: object

# %%
print("Mostre as 10 primeiras linhas usando iloc.")

print(df.iloc[:10])
# Out:
# Mostre as 10 primeiras linhas usando iloc.
#              timestamp  temperatura_ar  umidade_relativa  amonia  \
# 0  2025-01-01 00:00:00           21.65             85.66   15.81
# 1  2025-01-01 00:15:00           21.09             86.28   13.92
# 2  2025-01-01 00:30:00           20.75             88.13   10.84
# 3  2025-01-01 00:45:00           20.82             85.07   10.59
# 4  2025-01-01 01:00:00           20.13             88.95    8.47
# 5  2025-01-01 01:15:00           20.96             88.60    8.44
# 6  2025-01-01 01:30:00           20.02             89.48   12.94
# 7  2025-01-01 01:45:00           19.89             89.18   16.63
# 8  2025-01-01 02:00:00           20.05             88.24    8.95
# 9  2025-01-01 02:15:00           20.10             87.02   12.49
#
#    temperatura_globo_negro  ponto_orvalho   itgu
# 0                    23.68          19.14  72.07
# 1                    23.81          18.70  72.04
# 2                    22.47          18.71  70.71
# 3                    21.57          18.22  69.62
# 4                    21.73          18.25  69.80
# 5                    22.01          19.00  70.35
# 6                    21.23          18.24  69.30
# 7                    21.37          18.06  69.37
# 8                    21.99          18.05  69.99
# 9                    20.86          17.87  68.79

# %%
print("Mostre somente a coluna temperatura_ar usando iloc.")

print(df.iloc[:,1])
# Out:
# Mostre somente a coluna temperatura_ar usando iloc.
# 0      21.65
# 1      21.09
# 2      20.75
# 3      20.82
# 4      20.13
#        ...
# 667    23.33
# 668    22.84
# 669    22.52
# 670    22.32
# 671    21.87
# Name: temperatura_ar, Length: 672, dtype: float64

# %%
print("Mostre somente:temperatura_ar, amonia e itgu")

print(df.iloc[:, [0, 1, 2]])
